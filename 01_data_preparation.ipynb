# %% [markdown]
# # Data Preparation for Nutritional Composition Wildmeat
#
# This notebook organizes and cleans the raw dataset of wild meat nutritional composition, laying the groundwork for reliable analysis and imputation.

# %% [markdown]
# ## Overview
# This notebook prepares the raw wild meat nutritional composition dataset by cleaning, selecting relevant columns, handling missing data, and extracting taxonomic information to enable downstream analysis.

# %%
import pandas as pd

pd.set_option("display.max_columns", 500)

# %% [markdown]
# ## Setup
#
# Import required libraries and configure pandas display options.

# %%
df = pd.read_csv("data/Thales_Planilha_Geral_MJ_JM_15_07 (2) (1).csv", sep=";")

# %% [markdown]
# ## Data Loading
#
# Load the raw dataset from CSV and specify the delimiter for correct parsing.

# %%
df
# Out:
#      OBS Código Amostra Reserva     Nome científico     Espécie     Classe  \
# 0    NaN   006C      A1    RDSM  Melanosuchus niger  Jacaré-açu    Répteis
# 1    NaN   006C      A2    RDSM  Melanosuchus niger  Jacaré-açu    Répteis
# 2    NaN   006C      A3    RDSM  Melanosuchus niger  Jacaré-açu    Répteis
# 3    NaN   029C      A1    RDSA      Cuniculus paca        Paca  Mamíferos
# 4    NaN   029C      A2    RDSA      Cuniculus paca        Paca  Mamíferos
# ..   ...    ...     ...     ...                 ...         ...        ...
# 994  NaN    NaN     NaN     NaN                 NaN         NaN        NaN
# 995  NaN    NaN     NaN     NaN                 NaN         NaN        NaN
# 996  NaN    NaN     NaN     NaN                 NaN         NaN        NaN
# 997  NaN    NaN     NaN     NaN                 NaN         NaN        NaN
# 998  NaN    NaN     NaN     NaN                 NaN         NaN        NaN
#
#      Umidade  Cinzas  Lipídios   Proteínas  Mg 24 (ug/g)  Fe 57 (ug/g)  \
# 0      76.57    4.41      18.55      92.85         79.60          2.72
# 1      76.57    4.86      17.03      90.83           NaN           NaN
# 2      76.57    4.79      18.57      92.02           NaN           NaN
# 3      71.17    4.56      17.68      86.08        615.04         46.64
# 4      71.17    4.61      18.19      86.77           NaN           NaN
# ..       ...     ...        ...        ...           ...           ...
# 994      NaN     NaN        NaN        NaN           NaN           NaN
# 995      NaN     NaN        NaN        NaN           NaN           NaN
# 996      NaN     NaN        NaN        NaN           NaN           NaN
# 997      NaN     NaN        NaN        NaN           NaN           NaN
# 998      NaN     NaN        NaN        NaN           NaN           NaN
#
#      Ag 107 (ng/g)  Al 27 (ug/g)  Ba 138 (ug/g)  Co 59 (ng/g)  Cu 63 (ug/g)  \
# 0             0.56          0.01           0.01          3.60          0.58
# 1              NaN           NaN            NaN           NaN           NaN
# 2              NaN           NaN            NaN           NaN           NaN
# 3             0.44        726.79          34.31          6.95          2.09
# 4              NaN           NaN            NaN           NaN           NaN
# ..             ...           ...            ...           ...           ...
# 994            NaN           NaN            NaN           NaN           NaN
# 995            NaN           NaN            NaN           NaN           NaN
# 996            NaN           NaN            NaN           NaN           NaN
# 997            NaN           NaN            NaN           NaN           NaN
# 998            NaN           NaN            NaN           NaN           NaN
#
#      Zn 66 (ug/g)  Se 82 (ng/g)  Ti 205 (ng/g)  Li 7 (ng/g)  Rb 85 (ug/g)  \
# 0           18.47        500.69           5.24         5.30         79.09
# 1             NaN           NaN            NaN          NaN           NaN
# 2             NaN           NaN            NaN          NaN           NaN
# 3           24.22        737.03           1.74         2.73         87.23
# 4             NaN           NaN            NaN          NaN           NaN
# ..            ...           ...            ...          ...           ...
# 994           NaN           NaN            NaN          NaN           NaN
# 995           NaN           NaN            NaN          NaN           NaN
# 996           NaN           NaN            NaN          NaN           NaN
# 997           NaN           NaN            NaN          NaN           NaN
# 998           NaN           NaN            NaN          NaN           NaN
#
#      Sr 88 (ug/g)  Cs 133 (ng/g)  Mn 55 (ng/g)  Ni 60 (ng/g)  U 238 (ng/g)  \
# 0            0.01         221.13        210.25          0.01          0.14
# 1             NaN            NaN           NaN           NaN           NaN
# 2             NaN            NaN           NaN           NaN           NaN
# 3          274.50        1622.04        217.62         77.49          0.20
# 4             NaN            NaN           NaN           NaN           NaN
# ..            ...            ...           ...           ...           ...
# 994           NaN            NaN           NaN           NaN           NaN
# 995           NaN            NaN           NaN           NaN           NaN
# 996           NaN            NaN           NaN           NaN           NaN
# 997           NaN            NaN           NaN           NaN           NaN
# 998           NaN            NaN           NaN           NaN           NaN
#
#      Sb 121 (ng/g)  Sn 118 (ng/g)  Te 130 (ng/g)  Hg 202 (ng/g)  As 75 (ng/g)  \
# 0             1.77           9.89           0.65        3435.75         63.42
# 1              NaN            NaN            NaN            NaN           NaN
# 2              NaN            NaN            NaN            NaN           NaN
# 3             6.13          21.54           0.01           0.01          5.50
# 4              NaN            NaN            NaN            NaN           NaN
# ..             ...            ...            ...            ...           ...
# 994            NaN            NaN            NaN            NaN           NaN
# 995            NaN            NaN            NaN            NaN           NaN
# 996            NaN            NaN            NaN            NaN           NaN
# 997            NaN            NaN            NaN            NaN           NaN
# 998            NaN            NaN            NaN            NaN           NaN
#
#      Cd 111 (ng/g)  Pb 208 (ng/g)
# 0             3.87           0.01
# 1              NaN            NaN
# 2              NaN            NaN
# 3            33.63         182.05
# 4              NaN            NaN
# ..             ...            ...
# 994            NaN            NaN
# 995            NaN            NaN
# 996            NaN            NaN
# 997            NaN            NaN
# 998            NaN            NaN
#
# [999 rows x 35 columns]

# %%
# Preview the first rows of the dataset to verify it loaded correctly
df.head()
# Out:
#    OBS Código Amostra Reserva     Nome científico     Espécie     Classe  \
# 0  NaN   006C      A1    RDSM  Melanosuchus niger  Jacaré-açu    Répteis
# 1  NaN   006C      A2    RDSM  Melanosuchus niger  Jacaré-açu    Répteis
# 2  NaN   006C      A3    RDSM  Melanosuchus niger  Jacaré-açu    Répteis
# 3  NaN   029C      A1    RDSA      Cuniculus paca        Paca  Mamíferos
# 4  NaN   029C      A2    RDSA      Cuniculus paca        Paca  Mamíferos
#
#    Umidade  Cinzas  Lipídios   Proteínas  Mg 24 (ug/g)  Fe 57 (ug/g)  \
# 0    76.57    4.41      18.55      92.85         79.60          2.72
# 1    76.57    4.86      17.03      90.83           NaN           NaN
# 2    76.57    4.79      18.57      92.02           NaN           NaN
# 3    71.17    4.56      17.68      86.08        615.04         46.64
# 4    71.17    4.61      18.19      86.77           NaN           NaN
#
#    Ag 107 (ng/g)  Al 27 (ug/g)  Ba 138 (ug/g)  Co 59 (ng/g)  Cu 63 (ug/g)  \
# 0           0.56          0.01           0.01          3.60          0.58
# 1            NaN           NaN            NaN           NaN           NaN
# 2            NaN           NaN            NaN           NaN           NaN
# 3           0.44        726.79          34.31          6.95          2.09
# 4            NaN           NaN            NaN           NaN           NaN
#
#    Zn 66 (ug/g)  Se 82 (ng/g)  Ti 205 (ng/g)  Li 7 (ng/g)  Rb 85 (ug/g)  \
# 0         18.47        500.69           5.24         5.30         79.09
# 1           NaN           NaN            NaN          NaN           NaN
# 2           NaN           NaN            NaN          NaN           NaN
# 3         24.22        737.03           1.74         2.73         87.23
# 4           NaN           NaN            NaN          NaN           NaN
#
#    Sr 88 (ug/g)  Cs 133 (ng/g)  Mn 55 (ng/g)  Ni 60 (ng/g)  U 238 (ng/g)  \
# 0          0.01         221.13        210.25          0.01          0.14
# 1           NaN            NaN           NaN           NaN           NaN
# 2           NaN            NaN           NaN           NaN           NaN
# 3        274.50        1622.04        217.62         77.49          0.20
# 4           NaN            NaN           NaN           NaN           NaN
#
#    Sb 121 (ng/g)  Sn 118 (ng/g)  Te 130 (ng/g)  Hg 202 (ng/g)  As 75 (ng/g)  \
# 0           1.77           9.89           0.65        3435.75         63.42
# 1            NaN            NaN            NaN            NaN           NaN
# 2            NaN            NaN            NaN            NaN           NaN
# 3           6.13          21.54           0.01           0.01          5.50
# 4            NaN            NaN            NaN            NaN           NaN
#
#    Cd 111 (ng/g)  Pb 208 (ng/g)
# 0           3.87           0.01
# 1            NaN            NaN
# 2            NaN            NaN
# 3          33.63         182.05
# 4            NaN            NaN

# %% [markdown]
# ## Preview Loaded Data
#
# Display the first few rows of the dataframe to verify successful loading.

# %%
df.dropna(subset=["Mg 24 (ug/g)"], inplace=True)
df
# Out:
#            OBS   Código Amostra Reserva      Nome científico         Espécie  \
# 0          NaN     006C      A1    RDSM   Melanosuchus niger      Jacaré-açu
# 3          NaN     029C      A1    RDSA       Cuniculus paca            Paca
# 6          NaN     038C      A1    RDSA       Cuniculus paca            Paca
# 9          NaN     041C      A1    RDSA     Mazama americana  Veado capoeira
# 12         NaN     043C      A1    RDSA       Cuniculus paca            Paca
# ..         ...      ...     ...     ...                  ...             ...
# 252  só micros  LOR007C     NaN    RDSM   Alouatta seniculus  Macaco Guariba
# 253  só micros  LOR002C     NaN    RDSM  Podocnemis unifilis         Tracajá
# 254  só micros  LOR003C     NaN    RDSM   Podocnemis expansa       Tartaruga
# 255  só micros  LOR004C     NaN    RDSM  Podocnemis unifilis         Tracajá
# 256  só micros  LOR006C     NaN    RDSM    ﻿Cairina moschata    Pato do mato
#
#         Classe  Umidade  Cinzas  Lipídios   Proteínas  Mg 24 (ug/g)  \
# 0      Répteis    76.57    4.41      18.55      92.85         79.60
# 3    Mamíferos    71.17    4.56      17.68      86.08        615.04
# 6    Mamíferos    72.26    3.70      22.44      85.21        297.82
# 9    Mamíferos    73.06    4.51      24.58      90.53        313.00
# 12   Mamíferos    75.58    4.52      20.24      87.68        194.56
# ..         ...      ...     ...        ...        ...           ...
# 252  Mamíferos    77.17     NaN        NaN        NaN        428.72
# 253    Répteis    81.46     NaN        NaN        NaN        420.65
# 254    Répteis    74.76     NaN        NaN        NaN        934.00
# 255    Répteis    76.90     NaN        NaN        NaN        596.56
# 256       Aves      NaN     NaN        NaN        NaN         75.68
#
#      Fe 57 (ug/g)  Ag 107 (ng/g)  Al 27 (ug/g)  Ba 138 (ug/g)  Co 59 (ng/g)  \
# 0            2.72           0.56          0.01           0.01          3.60
# 3           46.64           0.44        726.79          34.31          6.95
# 6           23.71           0.01          0.01           0.01          4.84
# 9           21.01           0.01      12056.64           0.01          4.49
# 12          25.26           0.01          0.01           0.01         12.52
# ..            ...            ...           ...            ...           ...
# 252         31.32            NaN           NaN          74.22         57.27
# 253        141.16            NaN           NaN        1041.39         25.48
# 254         36.80            NaN           NaN         644.29         34.93
# 255         46.72            NaN           NaN         398.33         29.47
# 256         23.74            NaN           NaN          73.78         71.87
#
#      Cu 63 (ug/g)  Zn 66 (ug/g)  Se 82 (ng/g)  Ti 205 (ng/g)  Li 7 (ng/g)  \
# 0            0.58         18.47        500.69           5.24         5.30
# 3            2.09         24.22        737.03           1.74         2.73
# 6            1.82         48.86        437.40           2.32        10.06
# 9            3.52         25.64        339.99           1.95         3.53
# 12           3.33         58.91        552.87           2.15        38.13
# ..            ...           ...           ...            ...          ...
# 252          7.79        228.08          3.27           5.99       144.13
# 253         17.38        245.98          0.40          20.31        19.09
# 254          4.77         88.92          4.63          43.33        10.93
# 255          4.36         76.40          0.51          13.59        26.42
# 256         49.84         61.53          2.49           3.24        19.13
#
#      Rb 85 (ug/g)  Sr 88 (ug/g)  Cs 133 (ng/g)  Mn 55 (ng/g)  Ni 60 (ng/g)  \
# 0           79.09          0.01         221.13        210.25          0.01
# 3           87.23        274.50        1622.04        217.62         77.49
# 6          101.83        241.04         473.04         47.92          0.01
# 9           39.43         46.55         639.45         97.52         32.50
# 12          68.99         59.23         430.14        132.09          6.71
# ..            ...           ...            ...           ...           ...
# 252        112.10          0.28           0.19          0.44        153.77
# 253         68.85          2.32           0.06          2.15         58.54
# 254        259.22          1.26           0.28          1.43         72.27
# 255        139.76          1.02           0.18          1.32        134.92
# 256        136.33          0.12           0.19          0.67         30.12
#
#      U 238 (ng/g)  Sb 121 (ng/g)  Sn 118 (ng/g)  Te 130 (ng/g)  Hg 202 (ng/g)  \
# 0            0.14           1.77           9.89           0.65        3435.75
# 3            0.20           6.13          21.54           0.01           0.01
# 6            0.01           0.00           6.91           0.02           6.18
# 9            0.18           3.13          23.20           0.10           3.31
# 12           0.01           0.46           6.13           0.01           0.01
# ..            ...            ...            ...            ...            ...
# 252          0.25           3.07          12.22            NaN           0.02
# 253          0.45           2.47          28.54            NaN           0.06
# 254          0.31           3.84          39.19            NaN           0.11
# 255          0.38           4.25          59.38            NaN           0.09
# 256          0.28           0.81          43.71            NaN           0.03
#
#      As 75 (ng/g)  Cd 111 (ng/g)  Pb 208 (ng/g)
# 0           63.42           3.87           0.01
# 3            5.50          33.63         182.05
# 6            8.70           9.41           0.01
# 9            6.54           0.90           0.01
# 12           6.50           2.69           0.01
# ..            ...            ...            ...
# 252         26.73        1841.17         167.35
# 253         23.53          20.21         101.33
# 254         31.71          20.13         104.42
# 255         43.99          27.24         102.26
# 256         31.75         266.81          70.49
#
# [89 rows x 35 columns]

# %% [markdown]
# ## Remove Missing Values for Magnesium
#
# Drop rows with missing values in the magnesium column to ensure accurate Mg analysis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 0 to 256
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OBS              16 non-null     object
#  1   Código           89 non-null     object
#  2   Amostra          83 non-null     object
#  3   Reserva          84 non-null     object
#  4   Nome científico  89 non-null     object
#  5   Espécie          89 non-null     object
#  6   Classe           89 non-null     object
#  7   Umidade          42 non-null     float64
#  8   Cinzas           83 non-null     float64
#  9   Lipídios         80 non-null     float64
#  10  Proteínas        83 non-null     float64
#  11  Mg 24 (ug/g)     89 non-null     float64
#  12  Fe 57 (ug/g)     89 non-null     float64
#  13  Ag 107 (ng/g)    68 non-null     float64
#  14  Al 27 (ug/g)     68 non-null     float64
#  15  Ba 138 (ug/g)    89 non-null     float64
#  16  Co 59 (ng/g)     89 non-null     float64
#  17  Cu 63 (ug/g)     89 non-null     float64
#  18  Zn 66 (ug/g)     89 non-null     float64
#  19  Se 82 (ng/g)     89 non-null     float64
#  20  Ti 205 (ng/g)    89 non-null     float64
#  21  Li 7 (ng/g)      89 non-null     float64
#  22  Rb 85 (ug/g)     89 non-null     float64
#  23  Sr 88 (ug/g)     89 non-null     float64
#  24  Cs 133 (ng/g)    89 non-null     float64
#  25  Mn 55 (ng/g)     88 non-null     float64
#  26  Ni 60 (ng/g)     88 non-null     float64
#  27  U 238 (ng/g)     89 non-null     float64
#  28  Sb 121 (ng/g)    89 non-null     float64
#  29  Sn 118 (ng/g)    89 non-null     float64
#  30  Te 130 (ng/g)    68 non-null     float64
#  31  Hg 202 (ng/g)    89 non-null     float64
#  32  As 75 (ng/g)     89 non-null     float64
#  33  Cd 111 (ng/g)    89 non-null     float64
#  34  Pb 208 (ng/g)    89 non-null     float64
# dtypes: float64(28), object(7)
# memory usage: 25.0+ KB

# %% [markdown]
# ## Initial Data Overview
#
# Inspect dataframe structure, data types, and non-null counts to understand dataset completeness.

# %%
df["Nome científico"].value_counts().sort_index()
# Out:
# Nome científico
# Alouatta seniculus             4
# Boa constrictor                1
# Busarellus nigricollis         1
# Caiman crocodilus              4
# Cebus apella                   1
# Crax globulosa                 3
# Cuniculus paca                27
# Dasyprocta fuliginosa          9
# Eunectes murinus               1
# Euphractus sexcinctus          4
# Mazama americana               5
# Melanosuchus niger             3
# Mergus octosetaceus            1
# Mesoclemmys raniceps           1
# Mitu tuberosum                 2
# Paleosuchus palpebrosus        1
# Penelope jacquaca              5
# Phalacrocorax brasilianus      1
# Pipile cumanensis              1
# Podocnemis expansa             1
# Podocnemis unifilis            2
# Porphyrio martinica            1
# Puma concolor                  1
# Tapirus terrestris             1
# Tayassu tajacu                 1
#  Podocnemis sextuberculata     1
# ﻿Cairina moschata              5
# ﻿Sotalia fluviatilis           1
# Name: count, dtype: int64

# %%
df["Reserva"].value_counts()
# Out:
# Reserva
# RDSA     53
# RDSM     20
# FLONA    11
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['OBS', 'Código', 'Amostra', 'Reserva', 'Nome científico', 'Espécie',
#        'Classe', 'Umidade', 'Cinzas', 'Lipídios ', 'Proteínas', 'Mg 24 (ug/g)',
#        'Fe 57 (ug/g)', 'Ag 107 (ng/g)', 'Al 27 (ug/g)', 'Ba 138 (ug/g)',
#        'Co 59 (ng/g)', 'Cu 63 (ug/g)', 'Zn 66 (ug/g)', 'Se 82 (ng/g)',
#        'Ti 205 (ng/g)', 'Li 7 (ng/g)', 'Rb 85 (ug/g)', 'Sr 88 (ug/g)',
#        'Cs 133 (ng/g)', 'Mn 55 (ng/g)', 'Ni 60 (ng/g)', 'U 238 (ng/g)',
#        'Sb 121 (ng/g)', 'Sn 118 (ng/g)', 'Te 130 (ng/g)', 'Hg 202 (ng/g)',
#        'As 75 (ng/g)', 'Cd 111 (ng/g)', 'Pb 208 (ng/g)'],
#       dtype='object')

# %% [markdown]
# ## Select Relevant Columns
# We select only the identifier and the nutritional element columns needed for downstream analysis.

# %%
df = df[
    [
        "Código",
        "Nome científico",
        "Umidade",
        "Cinzas",
        "Lipídios ",
        "Proteínas",
        "Mg 24 (ug/g)",
        "Fe 57 (ug/g)",
        "Ag 107 (ng/g)",
        "Al 27 (ug/g)",
        "Ba 138 (ug/g)",
        "Co 59 (ng/g)",
        "Cu 63 (ug/g)",
        "Zn 66 (ug/g)",
        "Se 82 (ng/g)",
        "Ti 205 (ng/g)",
        "Li 7 (ng/g)",
        "Rb 85 (ug/g)",
        "Sr 88 (ug/g)",
        "Cs 133 (ng/g)",
        "Mn 55 (ng/g)",
        "Ni 60 (ng/g)",
        "U 238 (ng/g)",
        "Sb 121 (ng/g)",
        "Sn 118 (ng/g)",
        "Te 130 (ng/g)",
        "Hg 202 (ng/g)",
        "As 75 (ng/g)",
        "Cd 111 (ng/g)",
        "Pb 208 (ng/g)",
    ]
]

# %% [markdown]
# ## Column Subsetting
#
# Select only relevant nutritional element columns and identifiers for downstream analysis.

# %%
df
# Out:
#       Código      Nome científico  Umidade  Cinzas  Lipídios   Proteínas  \
# 0       006C   Melanosuchus niger    76.57    4.41      18.55      92.85
# 3       029C       Cuniculus paca    71.17    4.56      17.68      86.08
# 6       038C       Cuniculus paca    72.26    3.70      22.44      85.21
# 9       041C     Mazama americana    73.06    4.51      24.58      90.53
# 12      043C       Cuniculus paca    75.58    4.52      20.24      87.68
# ..       ...                  ...      ...     ...        ...        ...
# 252  LOR007C   Alouatta seniculus    77.17     NaN        NaN        NaN
# 253  LOR002C  Podocnemis unifilis    81.46     NaN        NaN        NaN
# 254  LOR003C   Podocnemis expansa    74.76     NaN        NaN        NaN
# 255  LOR004C  Podocnemis unifilis    76.90     NaN        NaN        NaN
# 256  LOR006C    ﻿Cairina moschata      NaN     NaN        NaN        NaN
#
#      Mg 24 (ug/g)  Fe 57 (ug/g)  Ag 107 (ng/g)  Al 27 (ug/g)  Ba 138 (ug/g)  \
# 0           79.60          2.72           0.56          0.01           0.01
# 3          615.04         46.64           0.44        726.79          34.31
# 6          297.82         23.71           0.01          0.01           0.01
# 9          313.00         21.01           0.01      12056.64           0.01
# 12         194.56         25.26           0.01          0.01           0.01
# ..            ...           ...            ...           ...            ...
# 252        428.72         31.32            NaN           NaN          74.22
# 253        420.65        141.16            NaN           NaN        1041.39
# 254        934.00         36.80            NaN           NaN         644.29
# 255        596.56         46.72            NaN           NaN         398.33
# 256         75.68         23.74            NaN           NaN          73.78
#
#      Co 59 (ng/g)  Cu 63 (ug/g)  Zn 66 (ug/g)  Se 82 (ng/g)  Ti 205 (ng/g)  \
# 0            3.60          0.58         18.47        500.69           5.24
# 3            6.95          2.09         24.22        737.03           1.74
# 6            4.84          1.82         48.86        437.40           2.32
# 9            4.49          3.52         25.64        339.99           1.95
# 12          12.52          3.33         58.91        552.87           2.15
# ..            ...           ...           ...           ...            ...
# 252         57.27          7.79        228.08          3.27           5.99
# 253         25.48         17.38        245.98          0.40          20.31
# 254         34.93          4.77         88.92          4.63          43.33
# 255         29.47          4.36         76.40          0.51          13.59
# 256         71.87         49.84         61.53          2.49           3.24
#
#      Li 7 (ng/g)  Rb 85 (ug/g)  Sr 88 (ug/g)  Cs 133 (ng/g)  Mn 55 (ng/g)  \
# 0           5.30         79.09          0.01         221.13        210.25
# 3           2.73         87.23        274.50        1622.04        217.62
# 6          10.06        101.83        241.04         473.04         47.92
# 9           3.53         39.43         46.55         639.45         97.52
# 12         38.13         68.99         59.23         430.14        132.09
# ..           ...           ...           ...            ...           ...
# 252       144.13        112.10          0.28           0.19          0.44
# 253        19.09         68.85          2.32           0.06          2.15
# 254        10.93        259.22          1.26           0.28          1.43
# 255        26.42        139.76          1.02           0.18          1.32
# 256        19.13        136.33          0.12           0.19          0.67
#
#      Ni 60 (ng/g)  U 238 (ng/g)  Sb 121 (ng/g)  Sn 118 (ng/g)  Te 130 (ng/g)  \
# 0            0.01          0.14           1.77           9.89           0.65
# 3           77.49          0.20           6.13          21.54           0.01
# 6            0.01          0.01           0.00           6.91           0.02
# 9           32.50          0.18           3.13          23.20           0.10
# 12           6.71          0.01           0.46           6.13           0.01
# ..            ...           ...            ...            ...            ...
# 252        153.77          0.25           3.07          12.22            NaN
# 253         58.54          0.45           2.47          28.54            NaN
# 254         72.27          0.31           3.84          39.19            NaN
# 255        134.92          0.38           4.25          59.38            NaN
# 256         30.12          0.28           0.81          43.71            NaN
#
#      Hg 202 (ng/g)  As 75 (ng/g)  Cd 111 (ng/g)  Pb 208 (ng/g)
# 0          3435.75         63.42           3.87           0.01
# 3             0.01          5.50          33.63         182.05
# 6             6.18          8.70           9.41           0.01
# 9             3.31          6.54           0.90           0.01
# 12            0.01          6.50           2.69           0.01
# ..             ...           ...            ...            ...
# 252           0.02         26.73        1841.17         167.35
# 253           0.06         23.53          20.21         101.33
# 254           0.11         31.71          20.13         104.42
# 255           0.09         43.99          27.24         102.26
# 256           0.03         31.75         266.81          70.49
#
# [89 rows x 30 columns]

# %%
df["Nome científico"] = df["Nome científico"].str.replace("\xa0", " ")
df["Nome científico"] = df["Nome científico"].str.strip()
# Out:
# /tmp/ipykernel_237611/1865801449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nome científico"] = df["Nome científico"].str.replace("\xa0", " ")
# /tmp/ipykernel_237611/1865801449.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nome científico"] = df["Nome científico"].str.strip()

# %% [markdown]
# ## Scientific Name Cleaning
#
# Replace non-breaking spaces and trim entries to standardize the `Nome científico` column.

# %%
df["Gênero"] = df["Nome científico"].str.split(" ").str[0].str.strip().str.lower()
df["Espécie"] = df["Nome científico"].str.split(" ").str[1].str.strip().str.lower()
# Out:
# /tmp/ipykernel_237611/4120751089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gênero"] = df["Nome científico"].str.split(" ").str[0].str.strip().str.lower()
# /tmp/ipykernel_237611/4120751089.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Espécie"] = df["Nome científico"].str.split(" ").str[1].str.strip().str.lower()

# %% [markdown]
# ## Extract Genus and Species
#
# Split standardized scientific names into lowercase `Gênero` and `Espécie` columns for taxonomic analysis.

# %%
df
# Out:
#       Código      Nome científico  Umidade  Cinzas  Lipídios   Proteínas  \
# 0       006C   Melanosuchus niger    76.57    4.41      18.55      92.85
# 3       029C       Cuniculus paca    71.17    4.56      17.68      86.08
# 6       038C       Cuniculus paca    72.26    3.70      22.44      85.21
# 9       041C     Mazama americana    73.06    4.51      24.58      90.53
# 12      043C       Cuniculus paca    75.58    4.52      20.24      87.68
# ..       ...                  ...      ...     ...        ...        ...
# 252  LOR007C   Alouatta seniculus    77.17     NaN        NaN        NaN
# 253  LOR002C  Podocnemis unifilis    81.46     NaN        NaN        NaN
# 254  LOR003C   Podocnemis expansa    74.76     NaN        NaN        NaN
# 255  LOR004C  Podocnemis unifilis    76.90     NaN        NaN        NaN
# 256  LOR006C    ﻿Cairina moschata      NaN     NaN        NaN        NaN
#
#      Mg 24 (ug/g)  Fe 57 (ug/g)  Ag 107 (ng/g)  Al 27 (ug/g)  Ba 138 (ug/g)  \
# 0           79.60          2.72           0.56          0.01           0.01
# 3          615.04         46.64           0.44        726.79          34.31
# 6          297.82         23.71           0.01          0.01           0.01
# 9          313.00         21.01           0.01      12056.64           0.01
# 12         194.56         25.26           0.01          0.01           0.01
# ..            ...           ...            ...           ...            ...
# 252        428.72         31.32            NaN           NaN          74.22
# 253        420.65        141.16            NaN           NaN        1041.39
# 254        934.00         36.80            NaN           NaN         644.29
# 255        596.56         46.72            NaN           NaN         398.33
# 256         75.68         23.74            NaN           NaN          73.78
#
#      Co 59 (ng/g)  Cu 63 (ug/g)  Zn 66 (ug/g)  Se 82 (ng/g)  Ti 205 (ng/g)  \
# 0            3.60          0.58         18.47        500.69           5.24
# 3            6.95          2.09         24.22        737.03           1.74
# 6            4.84          1.82         48.86        437.40           2.32
# 9            4.49          3.52         25.64        339.99           1.95
# 12          12.52          3.33         58.91        552.87           2.15
# ..            ...           ...           ...           ...            ...
# 252         57.27          7.79        228.08          3.27           5.99
# 253         25.48         17.38        245.98          0.40          20.31
# 254         34.93          4.77         88.92          4.63          43.33
# 255         29.47          4.36         76.40          0.51          13.59
# 256         71.87         49.84         61.53          2.49           3.24
#
#      Li 7 (ng/g)  Rb 85 (ug/g)  Sr 88 (ug/g)  Cs 133 (ng/g)  Mn 55 (ng/g)  \
# 0           5.30         79.09          0.01         221.13        210.25
# 3           2.73         87.23        274.50        1622.04        217.62
# 6          10.06        101.83        241.04         473.04         47.92
# 9           3.53         39.43         46.55         639.45         97.52
# 12         38.13         68.99         59.23         430.14        132.09
# ..           ...           ...           ...            ...           ...
# 252       144.13        112.10          0.28           0.19          0.44
# 253        19.09         68.85          2.32           0.06          2.15
# 254        10.93        259.22          1.26           0.28          1.43
# 255        26.42        139.76          1.02           0.18          1.32
# 256        19.13        136.33          0.12           0.19          0.67
#
#      Ni 60 (ng/g)  U 238 (ng/g)  Sb 121 (ng/g)  Sn 118 (ng/g)  Te 130 (ng/g)  \
# 0            0.01          0.14           1.77           9.89           0.65
# 3           77.49          0.20           6.13          21.54           0.01
# 6            0.01          0.01           0.00           6.91           0.02
# 9           32.50          0.18           3.13          23.20           0.10
# 12           6.71          0.01           0.46           6.13           0.01
# ..            ...           ...            ...            ...            ...
# 252        153.77          0.25           3.07          12.22            NaN
# 253         58.54          0.45           2.47          28.54            NaN
# 254         72.27          0.31           3.84          39.19            NaN
# 255        134.92          0.38           4.25          59.38            NaN
# 256         30.12          0.28           0.81          43.71            NaN
#
#      Hg 202 (ng/g)  As 75 (ng/g)  Cd 111 (ng/g)  Pb 208 (ng/g)        Gênero  \
# 0          3435.75         63.42           3.87           0.01  melanosuchus
# 3             0.01          5.50          33.63         182.05     cuniculus
# 6             6.18          8.70           9.41           0.01     cuniculus
# 9             3.31          6.54           0.90           0.01        mazama
# 12            0.01          6.50           2.69           0.01     cuniculus
# ..             ...           ...            ...            ...           ...
# 252           0.02         26.73        1841.17         167.35      alouatta
# 253           0.06         23.53          20.21         101.33    podocnemis
# 254           0.11         31.71          20.13         104.42    podocnemis
# 255           0.09         43.99          27.24         102.26    podocnemis
# 256           0.03         31.75         266.81          70.49      ﻿cairina
#
#        Espécie
# 0        niger
# 3         paca
# 6         paca
# 9    americana
# 12        paca
# ..         ...
# 252  seniculus
# 253   unifilis
# 254    expansa
# 255   unifilis
# 256   moschata
#
# [89 rows x 32 columns]

# %%
df.drop(columns=["Nome científico"], inplace=True)
df
# Out:
# /tmp/ipykernel_237611/1069731999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Nome científico"], inplace=True)
#       Código  Umidade  Cinzas  Lipídios   Proteínas  Mg 24 (ug/g)  \
# 0       006C    76.57    4.41      18.55      92.85         79.60
# 3       029C    71.17    4.56      17.68      86.08        615.04
# 6       038C    72.26    3.70      22.44      85.21        297.82
# 9       041C    73.06    4.51      24.58      90.53        313.00
# 12      043C    75.58    4.52      20.24      87.68        194.56
# ..       ...      ...     ...        ...        ...           ...
# 252  LOR007C    77.17     NaN        NaN        NaN        428.72
# 253  LOR002C    81.46     NaN        NaN        NaN        420.65
# 254  LOR003C    74.76     NaN        NaN        NaN        934.00
# 255  LOR004C    76.90     NaN        NaN        NaN        596.56
# 256  LOR006C      NaN     NaN        NaN        NaN         75.68
#
#      Fe 57 (ug/g)  Ag 107 (ng/g)  Al 27 (ug/g)  Ba 138 (ug/g)  Co 59 (ng/g)  \
# 0            2.72           0.56          0.01           0.01          3.60
# 3           46.64           0.44        726.79          34.31          6.95
# 6           23.71           0.01          0.01           0.01          4.84
# 9           21.01           0.01      12056.64           0.01          4.49
# 12          25.26           0.01          0.01           0.01         12.52
# ..            ...            ...           ...            ...           ...
# 252         31.32            NaN           NaN          74.22         57.27
# 253        141.16            NaN           NaN        1041.39         25.48
# 254         36.80            NaN           NaN         644.29         34.93
# 255         46.72            NaN           NaN         398.33         29.47
# 256         23.74            NaN           NaN          73.78         71.87
#
#      Cu 63 (ug/g)  Zn 66 (ug/g)  Se 82 (ng/g)  Ti 205 (ng/g)  Li 7 (ng/g)  \
# 0            0.58         18.47        500.69           5.24         5.30
# 3            2.09         24.22        737.03           1.74         2.73
# 6            1.82         48.86        437.40           2.32        10.06
# 9            3.52         25.64        339.99           1.95         3.53
# 12           3.33         58.91        552.87           2.15        38.13
# ..            ...           ...           ...            ...          ...
# 252          7.79        228.08          3.27           5.99       144.13
# 253         17.38        245.98          0.40          20.31        19.09
# 254          4.77         88.92          4.63          43.33        10.93
# 255          4.36         76.40          0.51          13.59        26.42
# 256         49.84         61.53          2.49           3.24        19.13
#
#      Rb 85 (ug/g)  Sr 88 (ug/g)  Cs 133 (ng/g)  Mn 55 (ng/g)  Ni 60 (ng/g)  \
# 0           79.09          0.01         221.13        210.25          0.01
# 3           87.23        274.50        1622.04        217.62         77.49
# 6          101.83        241.04         473.04         47.92          0.01
# 9           39.43         46.55         639.45         97.52         32.50
# 12          68.99         59.23         430.14        132.09          6.71
# ..            ...           ...            ...           ...           ...
# 252        112.10          0.28           0.19          0.44        153.77
# 253         68.85          2.32           0.06          2.15         58.54
# 254        259.22          1.26           0.28          1.43         72.27
# 255        139.76          1.02           0.18          1.32        134.92
# 256        136.33          0.12           0.19          0.67         30.12
#
#      U 238 (ng/g)  Sb 121 (ng/g)  Sn 118 (ng/g)  Te 130 (ng/g)  Hg 202 (ng/g)  \
# 0            0.14           1.77           9.89           0.65        3435.75
# 3            0.20           6.13          21.54           0.01           0.01
# 6            0.01           0.00           6.91           0.02           6.18
# 9            0.18           3.13          23.20           0.10           3.31
# 12           0.01           0.46           6.13           0.01           0.01
# ..            ...            ...            ...            ...            ...
# 252          0.25           3.07          12.22            NaN           0.02
# 253          0.45           2.47          28.54            NaN           0.06
# 254          0.31           3.84          39.19            NaN           0.11
# 255          0.38           4.25          59.38            NaN           0.09
# 256          0.28           0.81          43.71            NaN           0.03
#
#      As 75 (ng/g)  Cd 111 (ng/g)  Pb 208 (ng/g)        Gênero    Espécie
# 0           63.42           3.87           0.01  melanosuchus      niger
# 3            5.50          33.63         182.05     cuniculus       paca
# 6            8.70           9.41           0.01     cuniculus       paca
# 9            6.54           0.90           0.01        mazama  americana
# 12           6.50           2.69           0.01     cuniculus       paca
# ..            ...            ...            ...           ...        ...
# 252         26.73        1841.17         167.35      alouatta  seniculus
# 253         23.53          20.21         101.33    podocnemis   unifilis
# 254         31.71          20.13         104.42    podocnemis    expansa
# 255         43.99          27.24         102.26    podocnemis   unifilis
# 256         31.75         266.81          70.49      ﻿cairina   moschata
#
# [89 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 0 to 256
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Código         89 non-null     object
#  1   Umidade        42 non-null     float64
#  2   Cinzas         83 non-null     float64
#  3   Lipídios       80 non-null     float64
#  4   Proteínas      83 non-null     float64
#  5   Mg 24 (ug/g)   89 non-null     float64
#  6   Fe 57 (ug/g)   89 non-null     float64
#  7   Ag 107 (ng/g)  68 non-null     float64
#  8   Al 27 (ug/g)   68 non-null     float64
#  9   Ba 138 (ug/g)  89 non-null     float64
#  10  Co 59 (ng/g)   89 non-null     float64
#  11  Cu 63 (ug/g)   89 non-null     float64
#  12  Zn 66 (ug/g)   89 non-null     float64
#  13  Se 82 (ng/g)   89 non-null     float64
#  14  Ti 205 (ng/g)  89 non-null     float64
#  15  Li 7 (ng/g)    89 non-null     float64
#  16  Rb 85 (ug/g)   89 non-null     float64
#  17  Sr 88 (ug/g)   89 non-null     float64
#  18  Cs 133 (ng/g)  89 non-null     float64
#  19  Mn 55 (ng/g)   88 non-null     float64
#  20  Ni 60 (ng/g)   88 non-null     float64
#  21  U 238 (ng/g)   89 non-null     float64
#  22  Sb 121 (ng/g)  89 non-null     float64
#  23  Sn 118 (ng/g)  89 non-null     float64
#  24  Te 130 (ng/g)  68 non-null     float64
#  25  Hg 202 (ng/g)  89 non-null     float64
#  26  As 75 (ng/g)   89 non-null     float64
#  27  Cd 111 (ng/g)  89 non-null     float64
#  28  Pb 208 (ng/g)  89 non-null     float64
#  29  Gênero         89 non-null     object
#  30  Espécie        89 non-null     object
# dtypes: float64(28), object(3)
# memory usage: 22.2+ KB

# %%
cols_to_impute = [col for col in df.columns if df[col].isnull().sum() > 0]
cols_to_impute
# Out:
# ['Umidade',
#  'Cinzas',
#  'Lipídios ',
#  'Proteínas',
#  'Ag 107 (ng/g)',
#  'Al 27 (ug/g)',
#  'Mn 55 (ng/g)',
#  'Ni 60 (ng/g)',
#  'Te 130 (ng/g)']

# %% [markdown]
# ## Identify Missing Data for Imputation
# Determine which columns have missing values and count them to prioritize the imputation order.

# %%
order_to_impute = {}

for col in cols_to_impute:
    order_to_impute[col] = df[col].isnull().sum()

order_to_impute = {k: v for k, v in sorted(order_to_impute.items(), key=lambda item: item[1])}

order_to_impute
# Out:
# {'Mn 55 (ng/g)': np.int64(1),
#  'Ni 60 (ng/g)': np.int64(1),
#  'Cinzas': np.int64(6),
#  'Proteínas': np.int64(6),
#  'Lipídios ': np.int64(9),
#  'Ag 107 (ng/g)': np.int64(21),
#  'Al 27 (ug/g)': np.int64(21),
#  'Te 130 (ng/g)': np.int64(21),
#  'Umidade': np.int64(47)}

# %% [markdown]
# ## Export Cleaned Data

# %%
df.to_parquet("data/01_cleaned.parquet", index=False)

# %% [markdown]
# ## Save Imputation Order
#
# Export the computed order of columns to impute based on missing value frequencies.

# %%
order_to_impute = {k: int(v) for k, v in order_to_impute.items()}

# %%
import json

with open("data/01_order_to_impute.json", "w") as f:
    json.dump(order_to_impute, f)
